# %% [markdown]
# ## How to make a shift

# %% [markdown]
# Let's import apple stock data
#
# https://finance.yahoo.com/quote/AAPL/history/

# %%
import pandas as pd

# %%
dados=pd.read_csv('AAPL.csv')

# %%
dados
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2021-06-25  133.460007  133.889999  132.809998  133.110001  132.353851
# 1    2021-06-28  133.410004  135.250000  133.350006  134.779999  134.014343
# 2    2021-06-29  134.800003  136.490005  134.350006  136.330002  135.555542
# 3    2021-06-30  136.169998  137.410004  135.869995  136.960007  136.181976
# 4    2021-07-01  136.600006  137.330002  135.759995  137.270004  136.490189
# ..          ...         ...         ...         ...         ...         ...
# 247  2022-06-17  130.070007  133.080002  129.809998  131.559998  131.559998
# 248  2022-06-21  133.419998  137.059998  133.320007  135.869995  135.869995
# 249  2022-06-22  134.789993  137.759995  133.910004  135.350006  135.350006
# 250  2022-06-23  136.820007  138.589996  135.630005  138.270004  138.270004
# 251  2022-06-24  139.899994  141.910004  139.770004  141.660004  141.660004
#
#         Volume
# 0     70783700
# 1     62111300
# ...

# %%
dados['close_yesterday']=dados['Close'].shift(1)

# %%
dados
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 0    2021-06-25  133.460007  133.889999  132.809998  133.110001  132.353851
# 1    2021-06-28  133.410004  135.250000  133.350006  134.779999  134.014343
# 2    2021-06-29  134.800003  136.490005  134.350006  136.330002  135.555542
# 3    2021-06-30  136.169998  137.410004  135.869995  136.960007  136.181976
# 4    2021-07-01  136.600006  137.330002  135.759995  137.270004  136.490189
# ..          ...         ...         ...         ...         ...         ...
# 247  2022-06-17  130.070007  133.080002  129.809998  131.559998  131.559998
# 248  2022-06-21  133.419998  137.059998  133.320007  135.869995  135.869995
# 249  2022-06-22  134.789993  137.759995  133.910004  135.350006  135.350006
# 250  2022-06-23  136.820007  138.589996  135.630005  138.270004  138.270004
# 251  2022-06-24  139.899994  141.910004  139.770004  141.660004  141.660004
#
#         Volume  close_ontem  close_yesterday
# ...

# %% [markdown]
# What was done: We tossed the information from the previous day that was on the top line to the bottom line so that we can see how stock closed the day before and the next day on the same line.
# Below, a new column with the percentage change from one day to the next.

# %%
dados['altered %']=((dados['Close']/dados['close_yesterday'])-1)*100

# %%
dados.head(20)
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 0   2021-06-25  133.460007  133.889999  132.809998  133.110001  132.353851
# 1   2021-06-28  133.410004  135.250000  133.350006  134.779999  134.014343
# 2   2021-06-29  134.800003  136.490005  134.350006  136.330002  135.555542
# 3   2021-06-30  136.169998  137.410004  135.869995  136.960007  136.181976
# 4   2021-07-01  136.600006  137.330002  135.759995  137.270004  136.490189
# 5   2021-07-02  137.899994  140.000000  137.750000  139.960007  139.164917
# 6   2021-07-06  140.070007  143.149994  140.070007  142.020004  141.213211
# 7   2021-07-07  143.539993  144.889999  142.660004  144.570007  143.748734
# 8   2021-07-08  141.580002  144.059998  140.669998  143.240005  142.426300
# 9   2021-07-09  142.750000  145.649994  142.649994  145.110001  144.285675
# 10  2021-07-12  146.210007  146.320007  144.000000  144.500000  143.679138
# ...

# %%
dados.dropna(subset=['altered %'], inplace=True)

# %%
dados
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 1    2021-06-28  133.410004  135.250000  133.350006  134.779999  134.014343
# 2    2021-06-29  134.800003  136.490005  134.350006  136.330002  135.555542
# 3    2021-06-30  136.169998  137.410004  135.869995  136.960007  136.181976
# 4    2021-07-01  136.600006  137.330002  135.759995  137.270004  136.490189
# 5    2021-07-02  137.899994  140.000000  137.750000  139.960007  139.164917
# ..          ...         ...         ...         ...         ...         ...
# 247  2022-06-17  130.070007  133.080002  129.809998  131.559998  131.559998
# 248  2022-06-21  133.419998  137.059998  133.320007  135.869995  135.869995
# 249  2022-06-22  134.789993  137.759995  133.910004  135.350006  135.350006
# 250  2022-06-23  136.820007  138.589996  135.630005  138.270004  138.270004
# 251  2022-06-24  139.899994  141.910004  139.770004  141.660004  141.660004
#
#         Volume  close_ontem  close_yesterday  altered %
# ...

# %%
dados.describe(include ='all')
# Out:
#               Date        Open        High         Low       Close  \
# count          251  251.000000  251.000000  251.000000  251.000000
# unique         251         NaN         NaN         NaN         NaN
# top     2021-06-28         NaN         NaN         NaN         NaN
# freq             1         NaN         NaN         NaN         NaN
# mean           NaN  156.027849  157.953227  154.286095  156.195339
# std            NaN   12.792081   12.919557   12.506060   12.700596
# min            NaN  130.070007  132.389999  129.039993  130.059998
# 25%            NaN  146.205002  147.814995  145.254998  146.254998
# 50%            NaN  152.580002  154.720001  150.639999  152.509995
# 75%            NaN  167.735001  169.774994  165.525002  166.894997
# max            NaN  182.630005  182.940002  179.119995  182.009995
#
#          Adj Close        Volume  close_ontem  close_yesterday   altered %
# count   251.000000  2.510000e+02   251.000000       251.000000  251.000000
# ...
